# %% [markdown]
# # Implementacion de LeNet5 a MNIST

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %% [markdown]
# Traemos de keras el dataset MNIST y lo dividimos en datos de entrenamiento, validacion y test.

# %%
(train_x, train_y), (test_x, test_y) = keras.datasets.mnist.load_data()
train_x = train_x / 255.0
test_x = test_x / 255.0
train_x = tf.expand_dims(train_x, 3)
test_x = tf.expand_dims(test_x, 3)
val_x = train_x[:5000]
val_y = train_y[:5000]

# %% [markdown]
# A continuacion implementamos el algoritmo de LeNet-5 de keras

# %%
lenet_5_model = keras.models.Sequential([
    keras.layers.Conv2D(6, kernel_size=5, strides=1,  activation='tanh', input_shape=train_x[0].shape, padding='same'), #C1
    keras.layers.AveragePooling2D(), #S2
    keras.layers.Conv2D(16, kernel_size=5, strides=1, activation='tanh', padding='valid'), #C3
    keras.layers.AveragePooling2D(), #S4
    keras.layers.Flatten(), #Flatten
    keras.layers.Dense(120, activation='tanh'), #C5
    keras.layers.Dense(84, activation='tanh'), #F6
    keras.layers.Dense(10, activation='softmax') #Output layer
])

# %%
lenet_5_model.compile(optimizer='adam', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
lenet_5_model.fit(train_x, train_y, epochs=5, validation_data=(val_x, val_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.2309 - accuracy: 0.9312 - val_loss: 0.0957 - val_accuracy: 0.9708
# Epoch 2/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0886 - accuracy: 0.9726 - val_loss: 0.0574 - val_accuracy: 0.9820
# Epoch 3/5
# 1875/1875 [==============================] - 40s 22ms/step - loss: 0.0585 - accuracy: 0.9821 - val_loss: 0.0367 - val_accuracy: 0.9904
# Epoch 4/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0454 - accuracy: 0.9855 - val_loss: 0.0283 - val_accuracy: 0.9924
# Epoch 5/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0364 - accuracy: 0.9885 - val_loss: 0.0244 - val_accuracy: 0.9926

# %%
lenet_5_model.evaluate(test_x, test_y)
# Out:
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0550 - accuracy: 0.9822
# [0.054991528391838074, 0.982200026512146]

# %% [markdown]
# https://towardsdatascience.com/understanding-and-implementing-lenet-5-cnn-architecture-deep-learning-a2d531ebc342

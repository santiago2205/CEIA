# %% [markdown]
# <a href="https://www.inove.com.ar"><img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center"></a>
#
#
# # Procesamiento de lenguaje natural
# ## Predicción de próxima palabra

# %% [markdown]
# ### Objetivo
# El objetivo es utilizar documentos / corpus para crear embeddings de palabras basado en ese contexto utilizando la layer Embedding de Keras. Se utilizará esos embeddings junto con layers LSTM para predeccir la próxima posible palabra.

# %%
import random
import io
import pickle

import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout

# %% [markdown]
# ### Datos
# Utilizaremos como dataset canciones de bandas de habla inglés.

# %%
# Descargar la carpeta de dataset
import os
import gdown
if os.access('./songs_dataset', os.F_OK) is False:
    if os.access('simpsons_dataset.zip', os.F_OK) is False:
        url = 'https://drive.google.com/uc?id=1VLVgb3fD02XrF2V5OruKvQTOT91juXcs&export=download'
        output = 'songs_dataset.zip'
        gdown.download(url, output, quiet=False)
    # !unzip -q songs_dataset.zip
else:
    print("El dataset ya se encuentra descargado")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VLVgb3fD02XrF2V5OruKvQTOT91juXcs&export=download
# To: /content/songs_dataset.zip
# 100%|██████████| 2.09M/2.09M [00:00<00:00, 95.2MB/s]

# %%
# Posibles bandas
os.listdir("./songs_dataset/")
# Out:
# ['jimi-hendrix.txt',
#  'eminem.txt',
#  'drake.txt',
#  'patti-smith.txt',
#  'nicki-minaj.txt',
#  'janisjoplin.txt',
#  'leonard-cohen.txt',
#  'missy-elliott.txt',
#  'lady-gaga.txt',
#  'prince.txt',
#  'nirvana.txt',
#  'ludacris.txt',
#  'rihanna.txt',
#  'bruce-springsteen.txt',
#  'michael-jackson.txt',
#  'cake.txt',
#  'blink-182.txt',
#  'radiohead.txt',
#  'Kanye_West.txt',
#  'Lil_Wayne.txt',
#  'bjork.txt',
#  'amy-winehouse.txt',
#  'lil-wayne.txt',
#  'nursery_rhymes.txt',
#  'lorde.txt',
#  'dickinson.txt',
#  'paul-simon.txt',
#  'dr-seuss.txt',
#  'britney-spears.txt',
#  'disney.txt',
#  'bob-dylan.txt',
#  'bieber.txt',
#  'al-green.txt',
#  'alicia-keys.txt',
#  'dolly-parton.txt',
#  'adele.txt',
#  'kanye.txt',
#  'bruno-mars.txt',
#  'johnny-cash.txt',
#  'joni-mitchell.txt',
#  'nickelback.txt',
#  'notorious_big.txt',
#  'notorious-big.txt',
#  'r-kelly.txt',
#  'dj-khaled.txt',
#  'kanye-west.txt',
#  'bob-marley.txt',
#  'beatles.txt',
#  'lin-manuel-miranda.txt']

# %%
# Armar el dataset utilizando salto de línea para separar las oraciones/docs
df = pd.read_csv('songs_dataset/bob-marley.txt', sep='/n', header=None)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#                                                    0
# 0                        "Don't worry about a thing,
# 1      'Cause every little thing gonna be all right.
# 2               Singin': "Don't worry about a thing,
# 3  'Cause every little thing gonna be all right!"...
# 4                        Smiled with the risin' sun,

# %%
print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 2218

# %% [markdown]
# ### 1 - Ejemplo de Preprocesamiento
# - Hay que transformar las oraciones en tokens.
# - Dichas oraciones hay que ajustarlas al tamaño fijo de nuestra sentencia de entrada al modelo.
# - Hay que separar las palabras objetivos (target) que el modelo debe predecir en cada sentencia armada.

# %%
from keras.preprocessing.text import Tokenizer # equivalente a ltokenizer de nltk
from keras.preprocessing.text import text_to_word_sequence # equivalente a word_teokenize de nltk
from keras.preprocessing.sequence import pad_sequences # se utilizará para padding

# largo de la secuencia, incluye seq input + word output
train_len = 4

# %%
# Ejemplo de como transformar una oración a tokens usando keras
text = df.loc[0,0]
text
# Out:
# '"Don\'t worry about a thing,'

# %%
tokens = text_to_word_sequence(text) # entran oraciones -> salen vectores de N posiciones (tokens)
tokens
# Out:
# ["don't", 'worry', 'about', 'a', 'thing']

# %% [markdown]
# 1.1 - Transformar las oraciones en secuencias (tokens) de palabras

# %%
# Recorrer todas las filas y transformar las oraciones
# en secuencias de palabras
sentence_tokens = []
for _, row in df[:None].iterrows():
    sentence_tokens.append(text_to_word_sequence(row[0]))

# %%
# Demos un vistazo
sentence_tokens[:2]
# Out:
# [["don't", 'worry', 'about', 'a', 'thing'],
#  ["'cause", 'every', 'little', 'thing', 'gonna', 'be', 'all', 'right']]

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []

for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences
# Out:
# [["don't", 'worry', 'about', 'a']]

# %% [markdown]
# 1.2 - Crear los vectores de palabras (word2vec)
#
# Ahora necesitamos pasarlos a números para que lo entienda la red y separar input de output.
# - El Input seran integers (word2vec)
# - Mientras que el output será one hot encodeado (labels) del tamaño del vocabulario

# %%
tok = Tokenizer() 

# El tokeinzer "aprende" las palabras que se usaran
# Se construye (fit) una vez por proyecto, se aplica N veces (tal cual un encoder)
tok.fit_on_texts(text_sequences) 

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# %%
# Ahora sequences tiene los números "ID", largo 4
sequences
# Out:
# [[1, 2, 3, 4]]

# %%
# Cantidad de casos (doc) de entrada
print(tok.document_count)
# Out:
# 1

# %%
# Cantidad de veces que aparece cada palabra
print(len(tok.word_counts))
# Out:
# 4

# %%
# El índice para cada palabra
# El sistema las ordena de las más populares a las menos populares
print(tok.word_index)
# Out:
# {"don't": 1, 'worry': 2, 'about': 3, 'a': 4}

# %%
# Cantidad de veces quea aparece cada palabra en cada "documento"
# (1 documento = 1 caso de entrada)
print(tok.word_docs)
# Out:
# defaultdict(<class 'int'>, {'worry': 1, "don't": 1, 'a': 1, 'about': 1})

# %% [markdown]
# ### 2 - Preprocesamiento completo
# Debemos realizar los mismos pasos que en el ejemplo anterior, pero antes de eso debemos transformar ese dataset de filas de oraciones en un texto completo continuo para poder extraer el vocabulario.

# %%
# Vistazo a las primeras filas
df.loc[:15,0]
# Out:
# 0                           "Don't worry about a thing,
# 1         'Cause every little thing gonna be all right.
# 2                  Singin': "Don't worry about a thing,
# 3     'Cause every little thing gonna be all right!"...
# 4                           Smiled with the risin' sun,
# 5                                    Three little birds
# 6                                  Perch by my doorstep
# 7                                   Singin' sweet songs
# 8                            Of melodies pure and true,
# 9     Sayin', ("This is my message to you-ou-ou:") S...
# 10       'Cause every little thing gonna be all right."
# 11    Singin': "Don't worry (don't worry) 'bout a th...
# 12    'Cause every little thing gonna be all right!"...
# 13                          Smiled with the risin' sun,
# 14                                   Three little birds
# 15                                 Perch by my doorstep
# Name: 0, dtype: object

# %%
# Concatenamos todos los rows en un solo valor
corpus = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=0)[0]
corpus
# Out:
# '"Don\'t worry about a thing, \'Cause every little thing gonna be all right. Singin\': "Don\'t worry about a thing, \'Cause every little thing gonna be all right!" Rise up this mornin\', Smiled with the risin\' sun, Three little birds Perch by my doorstep Singin\' sweet songs Of melodies pure and true, Sayin\', ("This is my message to you-ou-ou:") Singin\': "Don\'t worry \'bout a thing, \'Cause every little thing gonna be all right." Singin\': "Don\'t worry (don\'t worry) \'bout a thing, \'Cause every little thing gonna be all right!" Rise up this mornin\', Smiled with the risin\' sun, Three little birds Perch by my doorstep Singin\' sweet songs Of melodies pure and true, Sayin\', "This is my message to you-ou-ou:" Singin\': "Don\'t worry about a thing, worry about a thing, oh! Every little thing gonna be all right. Don\'t worry!" Singin\': "Don\'t worry about a thing" - I won\'t worry! "\'Cause every little thing gonna be all right." Singin\': "Don\'t worry about a thing, \'Cause every little thing gonna be all right" - I won\'t worry! Singin\': "Don\'t worry about a thing, \'Cause every little thing gonna be all right." Singin\': "Don\'t worry about a thing, oh no! \'Cause every little thing gonna be all right! /fadeout/ Here is a little song I wrote You might want to sing it note for note Don\'t worry be happy In every life we have some trouble When you worry you make it double Don\'t worry, be happy...... Ain\'t got no place to lay your head Somebody came and took your bed Don\'t worry, be happy The land lord say your rent is late He may have to litigate Don\'t worry, be happy Look at me I am happy Don\'t worry, be happy Here I give you my phone number When you worry call me I make you happy Don\'t worry, be happy Ain\'t got no cash, ain\'t got no style Ain\'t got no girl to make you smile But don\'t worry be happy Cause when you worry Your face will frown And that will bring everybody down So don\'t worry, be happy (now)..... There is this little song I wrote I hope you learn it note for note Like good little children Don\'t worry, be happy Listen to what I say In your life expect some trouble But when you worry You make it double Don\'t worry, be happy...... Don\'t worry don\'t do it, be happy Put a smile on your face Don\'t bring everybody down like this Don\'t worry, it will soon pass Whatever it is Don\'t worry, be happy One love, one heart Let\'s get together and feel all right Hear the children crying (One love) Hear the children crying (One heart) Sayin\', "Give thanks and praise to the Lord and I will feel all right Sayin\', "Let\'s get together and feel all right Whoa, whoa, whoa, whoa Let them all pass all their dirty remarks (one love) There is one question I\'d really love to ask (one heart) Is there a place for the hopeless sinner Who has hurt all mankind just to save his own? Believe me One love, one heart Let\'s get together and feel all right As it was in the beginning (one love) So shall it be in the end (one heart) Alright, give thanks and praise to the Lord and I will feel all right Let\'s get together and feel all right One more thing Let\'s get together to fight this Holy Armageddon (one love) So when the Man comes there will be no, no doom (one song) Have pity on those whose chances grow thinner There ain\'t no hiding place from the Father of Creation Sayin\', one love, one heart Let\'s get together and feel all right I\'m pleading to mankind (one love) Oh, Lord (one heart) whoa Give thanks and praise to the Lord and I will feel all right Let\'s get together and feel all right Give thanks and praise to the Lord and I will feel all right Let\'s get together and feel all right UH !Bad boys watcha gon,watcha gon,watcha gonna do? When sherif John Brown come for you? Let me! Whatcha wanna do? When they come for you? Bad boys,bad boys whatcha gonna do whatcha gonna do? When they come for you?Bad boys bad boys whatcha gonna do? Whatcha gonna do whatcha gonna do when they come for you? When you were eight an ...

# %%
# Transformar el corpus a tokens
tokens=text_to_word_sequence(corpus)
# Vistazo general de los primeros tokens
tokens[:20]
# Out:
# ["don't",
#  'worry',
#  'about',
#  'a',
#  'thing',
#  "'cause",
#  'every',
#  'little',
#  'thing',
#  'gonna',
#  'be',
#  'all',
#  'right',
#  "singin'",
#  "don't",
#  'worry',
#  'about',
#  'a',
#  'thing',
#  "'cause"]

# %%
print("Cantidad de tokens en el corpus:", len(tokens))
# Out:
# Cantidad de tokens en el corpus: 17963

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences[:20]
# Out:
# [["don't", 'worry', 'about', 'a'],
#  ['worry', 'about', 'a', 'thing'],
#  ['about', 'a', 'thing', "'cause"],
#  ['a', 'thing', "'cause", 'every'],
#  ['thing', "'cause", 'every', 'little'],
#  ["'cause", 'every', 'little', 'thing'],
#  ['every', 'little', 'thing', 'gonna'],
#  ['little', 'thing', 'gonna', 'be'],
#  ['thing', 'gonna', 'be', 'all'],
#  ['gonna', 'be', 'all', 'right'],
#  ['be', 'all', 'right', "singin'"],
#  ['all', 'right', "singin'", "don't"],
#  ['right', "singin'", "don't", 'worry'],
#  ["singin'", "don't", 'worry', 'about'],
#  ["don't", 'worry', 'about', 'a'],
#  ['worry', 'about', 'a', 'thing'],
#  ['about', 'a', 'thing', "'cause"],
#  ['a', 'thing', "'cause", 'every'],
#  ['thing', "'cause", 'every', 'little'],
#  ["'cause", 'every', 'little', 'thing']]

# %%
# Proceso de tokenizacion
tok = Tokenizer() 
tok.fit_on_texts(text_sequences) 

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# Damos un vistazo
sequences[:20]
# Out:
# [[17, 83, 91, 4],
#  [83, 91, 4, 56],
#  [91, 4, 56, 65],
#  [4, 56, 65, 62],
#  [56, 65, 62, 54],
#  [65, 62, 54, 56],
#  [62, 54, 56, 34],
#  [54, 56, 34, 12],
#  [56, 34, 12, 19],
#  [34, 12, 19, 27],
#  [12, 19, 27, 183],
#  [19, 27, 183, 17],
#  [27, 183, 17, 83],
#  [183, 17, 83, 91],
#  [17, 83, 91, 4],
#  [83, 91, 4, 56],
#  [91, 4, 56, 65],
#  [4, 56, 65, 62],
#  [56, 65, 62, 54],
#  [65, 62, 54, 56]]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 17959

# %% [markdown]
# ### 3 - Input y target

# %%
# Con numpy es muy fácil realizar el slicing de vectores
ex = np.array([[1,2,3,4],[5,6,7,8]])
ex
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
# Con numpy es muy fácil realizar el slicing de vectores
print("Dimension:", ex.shape)
print("Todos los elementos:", ex)
print("Todos los elementos menos el último:", ex[:, :-1])
# Out:
# Dimension: (2, 4)
# Todos los elementos: [[1 2 3 4]
#  [5 6 7 8]]
# Todos los elementos menos el último: [[1 2 3]
#  [5 6 7]]

# %%
input = ex[:,:-1] # todos los rows, menos la ultima col
target = ex[:, -1] # última col de cada row

print("Input:", input)
print("Target:", target)
# Out:
# Input: [[1 2 3]
#  [5 6 7]]
# Target: [4 8]

# %%
arr_sequences = np.array(sequences)
x_data = arr_sequences[:,:-1]
y_data_int = arr_sequences[:,-1] # aún falta el oneHotEncoder

print(x_data.shape)
print(y_data_int.shape)
# Out:
# (17959, 3)
# (17959,)

# %%
# Palabras del vocabulario
tok.index_word
# Out:
# {1: 'the',
#  2: 'you',
#  3: 'i',
#  4: 'a',
#  5: 'to',
#  6: 'and',
#  7: 'no',
#  8: 'it',
#  9: 'in',
#  10: 'oh',
#  11: 'me',
#  12: 'be',
#  13: 'love',
#  14: 'is',
#  15: 'of',
#  16: 'yeah',
#  17: "don't",
#  18: 'so',
#  19: 'all',
#  20: 'we',
#  21: 'your',
#  22: 'my',
#  23: 'on',
#  24: 'for',
#  25: 'up',
#  26: 'now',
#  27: 'right',
#  28: 'down',
#  29: 'one',
#  30: 'say',
#  31: 'this',
#  32: 'know',
#  33: 'do',
#  34: 'gonna',
#  35: 'but',
#  36: 'they',
#  37: 'when',
#  38: 'got',
#  39: 'jah',
#  40: 'that',
#  41: "i'm",
#  42: 'de',
#  43: 'get',
#  44: 'come',
#  45: 'baby',
#  46: "we're",
#  47: 'will',
#  48: 'give',
#  49: 'from',
#  50: "it's",
#  51: 'like',
#  52: 'people',
#  53: 'there',
#  54: 'little',
#  55: "jammin'",
#  56: 'thing',
#  57: 'coming',
#  58: 'with',
#  59: 'what',
#  60: 'wanna',
#  61: 'said',
#  62: 'every',
#  63: 'can',
#  64: 'feel',
#  65: "'cause",
#  66: 'them',
#  67: 'was',
#  68: 'want',
#  69: 'let',
#  70: 'man',
#  71: "can't",
#  72: 'ooh',
#  73: 'na',
#  74: 'try',
#  75: 'just',
#  76: 'go',
#  77: 'see',
#  78: 'could',
#  79: 'lord',
#  80: 'more',
#  81: 'are',
#  82: 'take',
#  83: 'worry',
#  84: 'stand',
#  85: 'heart',
#  86: 'through',
#  87: 'dread',
#  88: 'good',
#  89: 'time',
#  90: 'easy',
#  91: 'about',
#  92: 'life',
#  93: 'some',
#  94: 'together',
#  95: 'much',
#  96: 'never',
#  97: 'simmer',
#  98: 'woman',
#  99: 'yoy',
#  100: 'stir',
#  101: "won't",
#  102: 'have',
#  103: 'need',
#  104: 'ya',
#  105: 'day',
#  106: 'then',
#  107: 'back',
#  108: 'uh',
#  109: 'she',
#  110: 'hammer',
#  111: 'soul',
#  112: "'pon",
#  113: 'if',
#  114: 'cry',
#  115: 'forever',
#  116: 'whatcha',
#  117: 'rock',
#  118: 'town',
#  119: 'move',
#  120: 'bad',
#  121: "we'll",
#  122: 'very',
#  123: 'doo',
#  124: 'wo',
#  125: 'away',
#  126: 'youths',
#  127: 'children',
#  128: "i'll",
#  129: 'race',
#  130: 'rammer',
#  131: 'heathen',
#  132: 'sweet',
#  133: 'he',
#  134: "you're",
#  135: 'wop',
#  136: 'rebel',
#  137: 'wall',
#  138: 'hear',
#  139: 'why',
#  140: 'here',
#  141: 'boys',
#  142: 'our',
#  143: 'ganja',
#  144: 'not',
#  145: 'loved',
#  146: 'world',
#  147: 'tell',
#  148: 'loving',
#  149: "i've",
#  150: 'long',
#  151: 'where',
#  152: 'us',
#  153: 'bomb',
#  154: "let's",
#  155: "that's",
#  156: 'fire',
#  157: 'choo',
#  158: 'cok',
#  159: 'movement',
#  160: 'make',
#  161: 'who',
#  162: 'fight',
#  163: 'would',
#  164: 'something',
#  165: 'carry',
#  166: 'rat',
#  167: "ain't",
#  168: 'look',
#  169: 'too',
#  170: 'gone',
#  171: 'how',
#  172: 'africa',
#  173: 'yo',
#  174: 'woo',
#  175: 'am',
#  176: 'their',
#  177: 'jamaica',
#  178: 'cluck',
#  179: 'skanking',
#  180: 'darling',
#  181: 'oo',
#  182: 'music',
#  183: "singin'",
#  184: 'by',
#  185: 'way',
#  186: 'while',
#  187: 'things',
#  188: 'woe',
#  189: 'well',
#  190: 'unite',
#  191: 'trench',
#  192: "you've",
#  193: 'place',
#  194: 'at',
#  195: 'as',
#  196: 'hit',
#  197: 'goes',
#  198: 'exodus',
#  199: 'war',
#  200: 'rights',
#  201: 'keep',
#  202: 'talk',
#  203: 'been',
#  204: 'happy',
#  205: 'whoa',
#  206: 'great',
#  207: 'yes',
#  208: 'wait',
#  209: 'vain',
#  210: 'again',
#  211: 'la',
#  212: 'songs',
#  213: 'trouble',
#  214: "i'd",
#  215: 'fool',
#  216: 'over',
#  217: "everything's",
#  218: "y'all",
#  219: 'natty',
#  220: 'chuck',
#  221: 'jam',
#  222: 'around',
#  223: 'think',
#  224: 'kingston',
#  225: "pimper's",
#  226: 'paradise',
#  227: 'cold',
#  228: 'pyaka',
#  229: 'refuse',
#  230: "sayin'",
#  231: 'head',
#  232: 'thanks',
#  233: "darlin'",
#  234: 'ever',
#  235: 'dey',
#  236: 'night',
#  237: 'fighting',
#  238: 'satisfy',
#  239: 'dem',
#  240: 'galang',
#  241: 'sun',
#  242: 'must',
#  243: 'soldier',
#  244: "we've",
#  245: 'forget',
#  246: 'dry',
#  247: 'whoo',
#  248: 'morning',
#  249: 'out',
#  250: 'another',
#  251: 'tonight',
#  252: 'shot',
#  253: 'always',
#  254: 'calling',
#  255: 'stone',
#  256: 'smile',
#  257: 'hope',
#  258: 'praise',
#  259: 'had',
#  260: 'eyes',
#  261: "'ypocrites",
#  262: 'part',
#  263: 'buffalo',
#  264: 'sheriff',
#  265: "she's",
#  266: 'deh',
#  267: 'cut',
#  268: 'roots',
#  269: 'cornerstone',
#  270: 'slow',
#  271: 'babylon',
#  272: 'his',
#  273: 'alright',
#  274: 'brown',
#  275: 'tears',
#  276: 'only',
#  277: 'until',
#  278: 'bob',
#  279: 'marley',
#  280: 'before',
#  281: 'zion',
#  282: 'woy',
#  283: 'live',
#  284: 'living',
#  285: 'everything',
#  286: "didn't",
#  287: 'deputy',
#  288: 'fall',
#  289: 'slogans',
#  290: 'home',
#  291: 'new',
#  292: 'builder',
#  293: 'land',
#  294: 'own',
#  295: 'believe',
#  296: 'holy',
#  297: 'nobody',
#  298: 'help',
#  299: 'truth',
#  300: 'first',
#  301: 'someone',
#  302: 'o',
#  303: 'today',
#  304: 'pain',
#  305: 'god',
#  306: 'party',
#  307: 'vibration',
#  308: 'shoot',
#  309: 'fly',
#  310: 'teach',
#  311: 'positive',
#  312: 'taking',
#  313: 'ride',
#  314: 'blame',
#  315: 'rise',
#  316: 'three',
#  317: 'call',
#  318: 'listen',
#  319: 'shall',
#  320: 'stop',
#  321: 'freedom',
#  322: 'mount',
#  323: 'america',
#  324: 'pale',
#  325: 'going',
#  326: 'woah',
#  327: "there's",
#  328: 'turn',
#  329: 'shakedown',
#  330: 'dance',
#  331: 'found',
#  332: 'twelve',
#  333: 'system',
#  334: 'hey',
#  335: 'men',
#  336: 'walk',
#  337: 'moving',
#  338: 'ment',
#  339: 'quick',
#  340: 'hungry',
#  341: 'ask',
#  342: 'end',
#  343: 'brother',
#  344: 'cook',
#  345: 'redemption',
#  346: "feelin'",
#  347: "smoke'a",
#  348: 'gun',
#  349: 'many',
#  350: 'or',
#  351: 'still',
#  352: 'than',
#  353: 'whop',
#  354: 'waiting',
#  355: 'belly',
#  356: 'nice',
#  357: 'water',
#  358: "groovin'",
#  359: 'guava',
#  360: 'african',
#  361: 'ism',
#  362: 'cup',
#  363: 'mr',
#  364: 'should',
#  365: 'sunshine',
#  366: 'throw',
#  367: 'boat',
#  368: "pickin'",
#  369: 'bread',
#  370: 'given',
#  371: 'mob',
#  372: 'put',
#  373: 'soon',
#  374: 'remember',
#  375: 'used',
#  376: 'yard',
#  377: 'friends',
#  378: 'shed',
#  379: 'made',
#  380: 'these',
#  381: 'kill',
#  382: 'rasta',
#  383: 'yoe',
#  384: 'judge',
#  385: 'road',
#  386: 'else',
#  387: 'judging',
#  388: 'work',
#  389: 'two',
#  390: 'running',
#  391: 'ah',
#  392: 'light',
#  393: 'eh',
#  394: 'find',
#  395: 'evil',
#  396: "they're",
#  397: 'coffee',
#  398: 'top',
#  399: 'wise',
#  400: 'rain',
#  401: 'black',
#  402: 'ha',
#  403: "c'mon",
#  404: 'rastaman',
#  405: 'dready',
#  406: 'trodding',
#  407: 'winepress',
#  408: "chuckin'",
#  409: 'true',
#  410: "'bout",
#  411: 'song',
#  412: 'might',
#  413: 'sing',
#  414: 'came',
#  415: 'girl',
#  416: 'really',
#  417: 'has',
#  418: 'hurt',
#  419: 'mankind',
#  420: 'comes',
#  421: 'father',
#  422: 'creation',
#  423: 'hot',
#  424: 'did',
#  425: 'past',
#  426: 'share',
#  427: 'after',
#  428: 'yourself',
#  429: 'same',
#  430: "i'n'i",
#  431: 'better',
#  432: 'name',
#  433: 'blue',
#  434: 'pot',
#  435: 'run',
#  436: 'suffer',
#  437: 'pieces',
#  438: 'once',
#  439: 'survive',
#  440: 'matter',
#  441: "cryin'",
#  442: 'hold',
#  443: 'tight',
#  444: 'play',
#  445: 'ho',
#  446: 'dip',
#  447: 'pa',
#  448: 'whole',
#  449: 'best',
#  450: 'rides',
#  451: 'upsetting',
#  452: 'reason',
#  453: 'food',
#  454: 'wet',
#  455: 'hypocrites',
#  456: 'anytime',
#  457: 'su',
#  458: 'cap',
#  459: 'fit',
#  460: 'wear',
#  461: 'corn',
#  462: 'fowl',
#  463: 'hard',
#  464: 'protect',
#  465: 'po',
#  466: 'herbsman',
#  467: 'throne',
#  468: 'angry',
#  469: 'birds',
#  470: 'message',
#  471: 'fadeout',
#  472: 'may',
#  473: 'learn',
#  474: 'were',
#  475: 'mean',
#  476: 'human',
#  477: 'sit',
#  478: 'meet',
#  479: 'feet',
#  480: 'strong',
#  481: 'free',
#  482: 'treat',
#  483: 'solo',
#  484: 'big',
#  485: 'last',
#  486: 'battle',
#  487: 'door',
#  488: 'behind',
#  489: 'ready',
#  490: 'satisfied',
#  491: 'dreadlock',
#  492: 'brought',
#  493: 'arrival',
#  494: 'survival',
#  495: 'yea',
#  496: 'arms',
#  497: 'moonlight',
#  498: 'corner',
#  499: 'him',
#  500: 'leaving',
#  501: 'start',
#  502: 'wid',
#  503: 'alone',
#  504: 'reggae',
#  505: 'jelly',
#  506: 'philosophy',
#  507: 'understand',
#  508: 'drop',
#  509: 'ego',
#  510: 'wooh',
#  511: 'against',
#  512: 'bright',
#  513: 'full',
#  514: 'drift',
#  515: 'coffin',
#  516: 'wrong',
#  517: 'scaba',
#  518: 'blood',
#  519: 'sad',
#  520: 'send',
#  521: 'saying',
#  522: 'within',
#  523: 'pull',
#  524: 'majesty',
#  525: 'natural',
#  526: 'mystic',
#  527: 'blowing',
#  528: 'air',
#  529: 'word',
#  530: 'dirt',
#  531: 'tough',
#  532: "'nough",
#  533: "mornin'",
#  534: 'smiled',
#  535: "risin'",
#  536: 'doorstep',
#  537: 'melodies',
#  538: 'pure',
#  539: 'ou',
#  540: 'note',
#  541: 'cause',
#  542: 'face',
#  543: 'pass',
#  544: 'crying',
#  545: 'those',
#  546: 'school',
#  547: 'break',
#  548: 'government',
#  549: 'trenchtown',
#  550: 'lights',
#  551: 'please',
#  552: 'generation',
#  553: 'none',
#  554: 'self',
#  555: 'mind',
#  556: 'heads',
#  557: 'mc',
#  558: 'lyte',
#  559: 'anyhow',
#  560: 'done',
#  561: 'game',
#  562: 'repeats',
#  563: 'rap',
#  564: "troddin'",
#  565: 'gold',
#  566: 'wa',
#  567: 'told',
#  568: 'walking',
#  569: 'p',
#  570: 'capturer',
#  571: 'adventurer',
#  572: 'gotta',
#  573: 'babe',
#  574: 'teardrops',
#  575: 'remain',
#  576: 'leave',
#  577: 'brotherman',
#  578: 'rockers',
#  579: 'rub',
#  580: 'chorus',
#  581: 'everywhere',
#  582: 'illusion',
#  583: 'africans',
#  584: 'heaven',
#  585: 'high',
#  586: 'telling',
#  587: "holdin'",
#  588: 'ram',
#  589: 'feeling',
#  590: 'an',
#  591: 'feed',
#  592: 'tup',
#  593: 'rum',
#  594: 'gravalicious',
#  595: 'tomorrow',
#  596: 'lie',
#  597: 'shining',
#  598: 'king',
#  599: 'queen',
#  600: 'into',
#  601: 'stages',
#  602: 'its',
#  603: 'fe',
#  604: 'binghi',
#  605: 'talking',
#  606: 'open',
#  607: 'reality',
#  608: 'low',
#  609: 'laws',
#  610: 'slippery',
#  611: 'caution',
#  612: 'grimepit',
#  613: 'eat',
#  614: 'drink',
#  615: "callin'",
#  616: 'teachings',
#  617: 'devil',
#  618: 'red',
#  619: "father's",
#  620: 'easier',
#  621: 'soulful',
#  622: "takin'",
#  623: 'twice',
#  624: 'burning',
#  625: 'sufferers',
#  626: 'pirate',
#  627: 'double',
#  628: 'bed',
#  629: 'bring',
#  630: 'everybody',
#  631: 'expect',
#  632: 'dirty',
#  633: 'remarks',
#  634: 'question',
#  635: 'hopeless',
#  636: 'save',
#  637: 'beginning',
#  638: 'doom',
#  639: 'pity',
#  640: 'whose',
#  641: 'chances',
#  642: 'grow',
#  643: 'hiding',
#  644: 'watcha',
#  645: 'john',
#  646: 'rule',
#  647: 'mother',
#  648: 'sometime',
#  649: 'sister',
#  650: 'along',
#  651: "'ere",
#  652: 'which',
#  653: 'push',
#  654: 'old',
#  655: 'fear',
#  656: 'fulfill',
#  657: 'bong',
#  658: 'smoke',
#  659: "singing'",
#  660: 'struggle',
#  661: 'rules',
#  662: 'above',
#  663: 'sure',
#  664: 'poor',
#  665: 'knows',
#  666: 'resist',
#  667: 'lot',
#  668: 'win',
#  669: 'singing',
#  670: 'worth',
#  671: 'judgement',
#  672: 'stumble',
#  673: 'travel',
#  674: 'wide',
#  675: 'fine',
#  676: 'since',
#  677: 'wood',
#  678: "you'll",
#  679: 'dropped',
#  680: 'control',
#  681: 'hotter',
#  682: 'near',
#  683: 'steady',
#  684: "rockin'",
#  685: 'thank',
#  686: 'even',
#  687: 'weeping',
#  688: "man's",
#  689: 'peace',
#  690: 'invitation',
#  691: 'special',
#  692: 'vacation',
#  693: 'concentration',
#  694: 'doing',
#  695: 'chance',
#  696: 'track',
#  697: 'guilty',
#  698: 'rama',
#  699: 'bee',
#  700: 'stock',
#  701: "'em",
#  702: 'though',
#  703: 'sorrow',
#  704: "lovin'",
#  705: 'rescue',
#  706: 'everyone',
#  707: 'dawn',
#  708: 'bado',
#  709: 'nowhere',
#  710: 'hate',
#  711: 'mandeville',
#  712: 'sligoville',
#  713: 'asking',
#  714: 'street',
#  715: 'cast',
#  716: 'rages',
#  717: 'hits',
#  718: 'reap',
#  719: 'sow',
#  720: 'iration',
#  721: "talkin'",
#  722: 'closed',
#  723: 'biggest',
#  724: 'bless',
#  725: 'youth',
#  726: 'likely',
#  727: 'ground',
#  728: 'crazy',
#  729: 'motherfunky',
#  730: 'friend',
#  731: 'sweepstake',
#  732: 'winner',
#  733: 'honey',
#  734: 'gap',
#  735: 'drumbeat',
#  736: 'riddim',
#  737: "jah's",
#  738: 'carefully',
#  739: 'tribulation',
#  740: 'lives',
#  741: 'needs',
#  742: 'bit',
#  743: 'spliff',
#  744: 'lift',
#  745: 'riff',
#  746: 'iyaman',
#  747: 'uniting',
#  748: 'slave',
#  749: 'remembrance',
#  750: 'company',
#  751: 'vampire',
#  752: "suckin'",
#  753: 'perch',
#  754: 'wrote',
#  755: 'took',
#  756: 'late',
#  757: 'sinner',
#  758: 'gon',
#  759: 'acting',
#  760: 'cool',
#  761: 'reflexion',
#  762: 'rude',
#  763: 'oba',
#  764: 'obaserving',
#  765: 'mingle',
#  766: 'lost',
#  767: 'future',
#  768: 'seh',
#  769: 'georgie',
#  770: 'logwood',
#  771: "burnin'",
#  772: 'nights',
#  773: 'cornmeal',
#  774: 'porridge',
#  775: 'carriage',
#  776: 'sold',
#  777: 'minutes',
#  778: "'and",
#  779: 'almighty',
#  780: 'emancipate',
#  781: 'mental',
#  782: 'slavery',
#  783: 'atomic',
#  784: 'energy',
#  785: 'prophets',
#  786: 'aside',
#  787: 'book',
#  788: 'roof',
#  789: 'shelter',
#  790: 'single',
#  791: 'room',
#  792: 'vocal',
#  793: 'lucky',
#  794: 'pitch',
#  795: 'everyday',
#  796: 'pay',
#  797: 'price',
#  798: 'jammin',
#  799: 'yet',
#  800: 'claim',
#  801: 'years',
#  802: 'remained',
#  803: 'repeat',
#  804: 'cannot',
#  805: 'hide',
#  806: 'side',
#  807: 'straight',
#  808: 'stolen',
#  809: 'history',
#  810: "wouldn't",
#  811: 'ran',
#  812: 'hand',
#  813: 'driven',
#  814: 'neither',
#  815: 'nor',
#  816: 'bow',
#  817: 'met',
#  818: 'moment',
#  819: 'sight',
#  820: 'point',
#  821: 'fingers',
#  822: 'saxophone',
#  823: 'rocky',
#  824: 'hillside',
#  825: 'knock',
#  826: 'burn',
#  827: 'thirsty',
#  828: 'stick',
#  829: "lickin'",
#  830: 'temper',
#  831: 'chicken',
#  832: 'lonely',
#  833: 'heartaches',
#  834: 'darkness',
#  835: 'fittest',
#  836: 'stay',
#  837: 'groovy',
#  838: 'child',
#  839: 'pon',
#  840: 'class',
#  841: 'second',
#  842: 'color',
#  843: 'without',
#  844: 'brothers',
#  845: 'south',
#  846: 'victory',
#  847: 'under',
#  848: 'earth',
#  849: 'struggling',
#  850: 'tired',
#  851: 'skism',
#  852: "dyin'",
#  853: "goin'",
#  854: 'holding',
#  855: 'other',
#  856: 'swear',
#  857: 'defense',
#  858: 'sudden',
#  859: 'bottom',
#  860: 'wee',
#  861: 'loves',
#  862: 'lose',
#  863: 'shelf',
#  864: 'diplomatic',
#  865: "'yp",
#  866: 'hypocratic',
#  867: 'tourist',
#  868: 'topper',
#  869: 'norris',
#  870: 'money',
#  871: 'lawyer',
#  872: 'replace',
#  873: "'eartache",
#  874: 'caused',
#  875: 'warm',
#  876: 'weather',
#  877: 'dancing',
#  878: 'gather',
#  879: 'rainbow',
#  880: 'seems',
#  881: 'fade',
#  882: 'girls',
#  883: 'surely',
#  884: 'palace',
#  885: 'll',
#  886: 'scoobado',
#  887: 'accumulate',
#  888: 'starts',
#  889: 'space',
#  890: 'e',
#  891: 'crows',
#  892: 'confusion',
#  893: 'prove',
#  894: "he's",
#  895: 'lean',
#  896: 'upon',
#  897: 'planted',
#  898: 'bringeth',
#  899: 'forth',
#  900: 'fruits',
#  901: 'season',
#  902: 'watch',
#  903: 'fish',
#  904: 'sprat',
#  905: 'slum',
#  906: 'brutalize',
#  907: 'da',
#  908: 'trash',
#  909: 'ourselves',
#  910: 'forsaken',
#  911: 'care',
#  912: 'nah',
#  913: 'flesh',
#  914: 'spiritual',
#  915: 'wickedness',
#  916: 'places',
#  917: 'firm',
#  918: 'praises',
#  919: 'justified',
#  920: 'housetop',
#  921: 'wicked',
#  922: 'rumor',
#  923: 'crumpy',
#  924: 'jet',
#  925: 'damp',
#  926: 'crampy',
#  927: 'tumbling',
#  928: 'forgive',
#  929: 'grown',
#  930: 'son',
#  931: 'city',
#  932: 'wipe',
#  933: 'streets',
#  934: 'pulpit',
#  935: 'wonder',
#  936: 'house',
#  937: 'worst',
#  938: 'enemy',
#  939: 'action',
#  940: 'bend',
#  941: 'sweep',
#  942: 'fallen',
#  943: 'fighters',
#  944: 'stance',
#  945: "'tis",
#  946: 'beats',
#  947: 'dying',
#  948: 'making',
#  949: 'playing',
#  950: 'frighten',
#  951: 'trumpet',
#  952: 'die',
#  953: 'roads',
#  954: 'trod',
#  955: 'moses',
#  956: 'across',
#  957: 'sea',
#  958: 'moon',
#  959: 'happiness',
#  960: 'ooooh',
#  961: 'created',
#  962: 'selassie',
#  963: 'rastafari',
#  964: 'irie',
#  965: 'ites',
#  966: 'sign',
#  967: 'beliefs',
#  968: 'armagiddyon',
#  969: 'grows',
#  970: "t'inner",
#  971: "pleadin'",
#  972: 'having',
#  973: 'fun',
#  974: 'spell',
#  975: 'yow',
#  976: 'excuse',
#  977: 'staying',
#  978: 'herb',
#  979: 'wine',
#  980: 'x4',
#  981: 'x3',
#  982: 'feels',
#  983: 'peeyah',
#  984: 'lee',
#  985: 'pleasant',
#  986: 'unification',
#  987: 'already',
#  988: 'benefit',
#  989: 'later',
#  990: 'linger',
#  991: 'concentrate',
#  992: 'scorn',
#  993: 'transplanted',
#  994: 'words',
#  995: 'sip',
#  996: 'woods',
#  997: 'destroying',
#  998: 'weight',
#  999: 'granted',
#  1000: 'teaching',
#  ...}

# %%
# Cantidad de palabras en el vocabulario
vocab_size = len(tok.word_counts)
vocab_size
# Out:
# 1639

# %%
# Transformar los datos a oneHotEncoding
y_data = to_categorical(y_data_int, num_classes=vocab_size)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-51c0d3e0c52c> in <module>()
#       1 # Transformar los datos a oneHotEncoding
# ----> 2 y_data = to_categorical(y_data_int, num_classes=vocab_size)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      73   n = y.shape[0]
#      74   categorical = np.zeros((n, num_classes), dtype=dtype)
# ---> 75   categorical[np.arange(n), y] = 1
#      76   output_shape = input_shape + (num_classes,)
#      77   categorical = np.reshape(categorical, output_shape)
#
# IndexError: index 1639 is out of bounds for axis 1 with size 1639

# %%
# En el caso anterior explota porque y_data_int comienza en "1" en vez de "0"
# valor minimo:
min(y_data_int)
# Out:
# 1

# %%
y_data_int_offset = y_data_int - 1
y_data = to_categorical(y_data_int_offset, num_classes=vocab_size) 
y_data.shape
# Out:
# (17959, 1639)

# %% [markdown]
# ### 4 - Entrenar el modelo

# %%
# largo de la secuencia de entrada
input_seq_len = x_data.shape[1] 
input_seq_len
# Out:
# 3

# %%
# Largo del vector de salida --> vocab_size
output_size = vocab_size
output_size
# Out:
# 1639

# %%
model = Sequential()

# Embedding:
# input_seq_len = 3 --> ingreso 3 palabras
# input_dim = vocab_size --> 1628 palabras distintas
# output_dim = 5 --> crear embeddings de tamaño 3 (tamaño variable y ajustable)
model.add(Embedding(input_dim=vocab_size+1, output_dim=5, input_length=input_seq_len))

model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64)) # La última capa LSTM no lleva return_sequences
model.add(Dense(32, activation='relu'))

# Predicción de clasificación con softmax
# La salida vuelve al espacio de 1628 palabras posibles
model.add(Dense(vocab_size, activation='softmax'))

# Clasificación multiple categórica --> loss = categorical_crossentropy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 3, 5)              8200
# _________________________________________________________________
# lstm (LSTM)                  (None, 3, 64)             17920
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 64)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1639)              54087
# =================================================================
# Total params: 115,311
# Trainable params: 115,311
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_data, y_data, epochs=50, validation_split=0.05)
# Out:
# Epoch 1/50
# 534/534 [==============================] - 5s 9ms/step - loss: 4.9909 - accuracy: 0.3402 - val_loss: 11.9517 - val_accuracy: 0.0256
# Epoch 2/50
# 534/534 [==============================] - 5s 9ms/step - loss: 3.7914 - accuracy: 0.3606 - val_loss: 11.2278 - val_accuracy: 0.0267
# Epoch 3/50
# 534/534 [==============================] - 5s 9ms/step - loss: 3.4505 - accuracy: 0.3859 - val_loss: 11.3141 - val_accuracy: 0.0256
# Epoch 4/50
# 534/534 [==============================] - 5s 9ms/step - loss: 3.2571 - accuracy: 0.3999 - val_loss: 11.5574 - val_accuracy: 0.0345
# Epoch 5/50
# 534/534 [==============================] - 5s 9ms/step - loss: 3.1237 - accuracy: 0.4129 - val_loss: 11.2894 - val_accuracy: 0.0791
# Epoch 6/50
# 534/534 [==============================] - 5s 9ms/step - loss: 3.0108 - accuracy: 0.4216 - val_loss: 11.5005 - val_accuracy: 0.0813
# Epoch 7/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.9332 - accuracy: 0.4279 - val_loss: 11.3116 - val_accuracy: 0.1036
# Epoch 8/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.8547 - accuracy: 0.4364 - val_loss: 11.5031 - val_accuracy: 0.0891
# Epoch 9/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.7895 - accuracy: 0.4383 - val_loss: 11.6191 - val_accuracy: 0.0958
# Epoch 10/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.7250 - accuracy: 0.4494 - val_loss: 11.5349 - val_accuracy: 0.0523
# Epoch 11/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.6768 - accuracy: 0.4520 - val_loss: 12.1714 - val_accuracy: 0.0512
# Epoch 12/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.6164 - accuracy: 0.4595 - val_loss: 11.9848 - val_accuracy: 0.0557
# Epoch 13/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.5864 - accuracy: 0.4645 - val_loss: 12.3581 - val_accuracy: 0.0535
# Epoch 14/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.5388 - accuracy: 0.4686 - val_loss: 12.7688 - val_accuracy: 0.1002
# Epoch 15/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.4940 - accuracy: 0.4760 - val_loss: 12.4679 - val_accuracy: 0.0902
# Epoch 16/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.4658 - accuracy: 0.4807 - val_loss: 12.2106 - val_accuracy: 0.1002
# Epoch 17/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.4360 - accuracy: 0.4813 - val_loss: 12.4104 - val_accuracy: 0.0980
# Epoch 18/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.4086 - accuracy: 0.4841 - val_loss: 12.5891 - val_accuracy: 0.1058
# Epoch 19/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.3681 - accuracy: 0.4905 - val_loss: 13.1950 - val_accuracy: 0.1069
# Epoch 20/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.3426 - accuracy: 0.4926 - val_loss: 13.1922 - val_accuracy: 0.0690
# Epoch 21/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.3179 - accuracy: 0.4981 - val_loss: 13.0359 - val_accuracy: 0.1125
# Epoch 22/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.2915 - accuracy: 0.5016 - val_loss: 13.1745 - val_accuracy: 0.1080
# Epoch 23/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.2688 - accuracy: 0.5039 - val_loss: 13.5297 - val_accuracy: 0.0713
# Epoch 24/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.2433 - accuracy: 0.5057 - val_loss: 13.6018 - val_accuracy: 0.1080
# Epoch 25/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.2252 - accuracy: 0.5067 - val_loss: 13.5106 - val_accuracy: 0.1169
# Epoch 26/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.1976 - accuracy: 0.5129 - val_loss: 13.9261 - val_accuracy: 0.1180
# Epoch 27/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.1822 - accuracy: 0.5150 - val_loss: 13.8980 - val_accuracy: 0.1169
# Epoch 28/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.1646 - accuracy: 0.5154 - val_loss: 13.9072 - val_accuracy: 0.1102
# Epoch 29/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.1442 - accuracy: 0.5169 - val_loss: 13.8105 - val_accuracy: 0.1203
# Epoch 30/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.1289 - accuracy: 0.5222 - val_loss: 13.6636 - val_accuracy: 0.1225
# Epoch 31/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.1178 - accuracy: 0.5239 - val_loss: 14.2469 - val_accuracy: 0.1203
# Epoch 32/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0967 - accuracy: 0.5286 - val_loss: 14.0746 - val_accuracy: 0.0846
# Epoch 33/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0723 - accuracy: 0.5266 - val_loss: 14.4330 - val_accuracy: 0.1269
# Epoch 34/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0661 - accuracy: 0.5317 - val_loss: 14.1952 - val_accuracy: 0.1180
# Epoch 35/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0631 - accuracy: 0.5302 - val_loss: 14.3144 - val_accuracy: 0.1192
# Epoch 36/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0486 - accuracy: 0.5357 - val_loss: 14.5053 - val_accuracy: 0.1381
# Epoch 37/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0405 - accuracy: 0.5375 - val_loss: 14.5251 - val_accuracy: 0.1359
# Epoch 38/50
# 534/534 [==============================] - 5s 9ms/step - loss: 2.0118 - accuracy: 0.5356 - val_loss: 14.8999 - val_accuracy: 0.1247
# Epoch 39/50
# 534/534 [==============================] - 5s 9ms/step - loss: 1.9947 - accuracy: 0.5399 - val_loss: 14.4324 - val_accuracy: 0.1392
# Epoch 40/50
# 534/534 [==============================] - 5s 9ms/step - loss: 1.9927 - accuracy: 0.5405 - val_loss: 14.9897 - val_accuracy: 0.1281
# Epoch 41/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.9869 - accuracy: 0.5450 - val_loss: 14.9647 - val_accuracy: 0.1370
# Epoch 42/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.9647 - accuracy: 0.5446 - val_loss: 14.9791 - val_accuracy: 0.1381
# Epoch 43/50
# 534/534 [==============================] - 5s 9ms/step - loss: 1.9725 - accuracy: 0.5439 - val_loss: 15.0517 - val_accuracy: 0.1214
# Epoch 44/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.9525 - accuracy: 0.5510 - val_loss: 15.1631 - val_accuracy: 0.1136
# Epoch 45/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.9355 - accuracy: 0.5504 - val_loss: 15.1502 - val_accuracy: 0.1448
# Epoch 46/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.9214 - accuracy: 0.5519 - val_loss: 15.7500 - val_accuracy: 0.1526
# Epoch 47/50
# 534/534 [==============================] - 5s 9ms/step - loss: 1.9192 - accuracy: 0.5522 - val_loss: 15.4972 - val_accuracy: 0.1648
# Epoch 48/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.8962 - accuracy: 0.5565 - val_loss: 15.8344 - val_accuracy: 0.1169
# Epoch 49/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.8930 - accuracy: 0.5622 - val_loss: 15.4612 - val_accuracy: 0.1559
# Epoch 50/50
# 534/534 [==============================] - 5s 10ms/step - loss: 1.8968 - accuracy: 0.5563 - val_loss: 15.7216 - val_accuracy: 0.1526

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Entrenamiento
epoch_count = range(1, len(hist.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_accuracy'], label='valid')
plt.show()

# %% [markdown]
# ### 5 - Predicción de próxima palabra

# %%
# Keras pad_sequences
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences
# Si la secuencia de entrada supera al input_seq_len (3) se trunca
# Si la secuencia es más corta se agregna ceros al comienzo

# %%
# Se utilizará gradio para ensayar el modelo
# Herramienta poderosa para crear interfaces rápidas para ensayar modelos
# https://gradio.app/
import sys
# !{sys.executable} -m pip install gradio --quiet
# Out:
#      |████████████████████████████████| 3.4 MB 5.3 MB/s
#      |████████████████████████████████| 206 kB 45.2 MB/s
#      |████████████████████████████████| 1.9 MB 35.1 MB/s
#      |████████████████████████████████| 63 kB 2.3 MB/s
#      |████████████████████████████████| 3.0 MB 35.4 MB/s
#      |████████████████████████████████| 961 kB 22.7 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for flask-cachebuster (setup.py) ... done

# %%
import gradio as gr

def model_response(human_text):

    # Encodeamos
    encoded = tok.texts_to_sequences([human_text])[0]
    # Si tienen distinto largo
    encoded = pad_sequences([encoded], maxlen=3, padding='pre')
    
    # Predicción softmax
    y_hat = model.predict(encoded).argmax(axis=-1)

    # Debemos buscar en el vocabulario la palabra
    # que corresopnde al indice (y_hat) predicho por le modelo
    out_word = ''
    for word, index in tok.word_index.items():
        if index == y_hat:
            out_word = word
            break

    # Agrego la palabra a la frase predicha
    return human_text + ' ' + out_word

iface = gr.Interface(
    fn=model_response,
    inputs=["textbox"],
    outputs="text",
    layout="vertical")

iface.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# This share link will expire in 72 hours. If you need a permanent link, visit: https://gradio.app/introducing-hosted
# Running on External URL: https://38734.gradio.app
# Interface loading below...
#         <iframe
#             width="900"
#             height="500"
#             src="https://38734.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-2a8fe09160a6> in <module>()
#      28     layout="vertical")
#      29
# ---> 30 iface.launch(debug=True)
#
# /usr/local/lib/python3.7/dist-packages/gradio/interface.py in launch(self, inline, inbrowser, share, debug, auth, auth_message, private_endpoint, prevent_thread_lock)
#     585             while True:
#     586                 sys.stdout.flush()
# --> 587                 time.sleep(0.1)
#     588         is_in_interactive_mode = bool(getattr(sys, 'ps1', sys.flags.interactive))
#     589         if not prevent_thread_lock and not is_in_interactive_mode:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 6 - Generación de secuencias nuevas

# %%
def generate_seq(model, tokenizer, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            tokenizer (keras tokenizer): tonenizer utilizado en el preprocesamiento
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de palabras a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	# generate a fixed number of words
    for _ in range(n_words):
		# Encodeamos
        encoded = tokenizer.texts_to_sequences([output_text])[0]
		# Si tienen distinto largo
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		
		# Predicción softmax
        y_hat = model.predict(encoded).argmax(axis=-1)
		# Vamos concatenando las predicciones
        out_word = ''

        # Debemos buscar en el vocabulario la palabra
        # que corresopnde al indice (y_hat) predicho por le modelo
        for word, index in tokenizer.word_index.items():
            if index == y_hat:
                out_word = word
                break

		# Agrego las palabras a la frase predicha
        output_text += ' ' + out_word
    return output_text

# %%
input_text='don\'t worry'

generate_seq(model, tok, input_text, max_length=3, n_words=2)
# Out:
# "don't worry me side"

# %% [markdown]
# ### 7 - Conclusiones
# El modelo entrenado tuvo un muy mail desempeño en el entrenamiento además de overfitting. Cuestiones que podrían mejorarse:
# - Agregar más capas o neuronaes
# - Incrementar la cantidad de épocas
# - Agregar BRNN
#
# Es importante destacar que en este ejemplo estamos entrenando nuestro propios Embeddings, y para ello se requiere mucha data. En los ejemplos que realizaremos de aquí en más utilizaremos más datos, embeddings pre-enternados o modelos pre-entrenados.
